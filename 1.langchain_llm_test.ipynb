# %% [markdown]
# ### 환경 설정과 LangChain의 ChatOpenAI를 활용한 검증

# %%
# %pip install langchain-openai python-dotenv

# %% [markdown]
# #### 환경변수 저장
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv

load_dotenv() #.env 파일에서 환경변수 로드 필요. 비용 발생
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name='gpt-4o-mini')

# %%
ai_message = llm.invoke("장기문서보관 신청방법?")
ai_message.content
# Out:
# '장기문서보관 신청 방법은 보관하고자 하는 문서의 종류나 관리 기관에 따라 다를 수 있습니다. 일반적으로는 다음과 같은 절차를 따릅니다:\n\n1. **보관할 문서 확인**: 보관하고 싶은 문서의 종류와 개수를 확인합니다. 이는 개인 문서일 수도 있고, 회사의 비즈니스 관련 문서일 수도 있습니다.\n\n2. **관리 기관 선택**: 문서를 보관할 기관을 결정합니다. 법원, 공공기관, 보안 문서 보관 서비스 업체 등 다양한 선택지가 있습니다.\n\n3. **신청서 제출**: 해당 기관의 웹사이트나 직접 방문하여 장기문서 보관 신청서를 작성하고 제출합니다. 필요 서류나 요금이 있을 수 있으니 미리 확인합니다.\n\n4. **안전성 검토**: 보관할 문서의 안전성을 검토합니다. 개인 정보가 포함된 문서라면 보안 관리 방침에 따라 추가적인 조치가 필요할 수 있습니다.\n\n5. **보관 계약 체결**: 보관 조건에 대한 계약을 체결합니다. 여기에는 보관 기간, 비용, 접근 권한 등에 대한 내용이 포함됩니다.\n\n6. **문서 인계**: 보관기관에 문서를 인계하고, 인계받은 증명을 받습니다.\n\n자세한 내용은 해당 기관의 안내를 따르거나 고객센터에 문의하여 확인하는 것이 좋습니다.'
