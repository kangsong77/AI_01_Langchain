# %% [markdown]
# #### 환경 설정과 LangChain의 ChatOllama를 활용한 검증
#
# 문서참조: https://reference.langchain.com/python/langchain-ollama/chat_models/ChatOllama

# %%
# %pip install -U langchain-ollama

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="exaone3.5:2.4b")

# %%
ai_message = llm.invoke("장기문서보관 신청방법?")
ai_message.content
# Out:
# '장기문서보관 신청 방법은 다음과 같습니다:\n\n1. **온라인 신청**:\n   - **신청사이트 방문**: 공식 문서 보관 서비스 웹사이트를 방문하세요.\n   - **회원가입/로그인**: 필요하다면 계정을 생성하거나 기존 계정으로 로그인합니다.\n   - **신청 양식 작성**: 개인정보 및 보관할 문서 정보를 정확하게 입력합니다.\n   - **서류 제출**: 스캔 또는 원본 문서를 업로드합니다. 파일 크기와 형식에 대한 제한 사항을 확인하세요.\n   - **처리 및 보관**: 제출한 후 처리 시간과 보관 기간에 대한 안내를 받게 됩니다.\n\n2. **전화 신청**:\n   - **고객센터 연락처 확인**: 공식 웹사이트나 관련 기관에서 제공하는 고객센터 전화번호를 확인합니다.\n   - **문의**: 신청 절차, 필요 서류, 비용 등에 대해 상세한 질문을 합니다.\n   - **신청 진행**: 담당자의 안내에 따라 필요한 정보를 제공하고 신청을 완료합니다.\n\n3. **직접 방문**:\n   - **주소 확인**: 공식 서비스 센터나 문서 보관 지점의 정확한 주소를 미리 확인합니다.\n   - **방문**: 방문 날짜와 시간을 맞추어 기관을 방문합니다.\n   - **상담 및 신청**: 직원과 상담 후 신청서를 작성하고 필요 서류를 제출합니다.\n\n**주의사항**:\n- **규정 준수**: 개인정보 보호법 및 관련 법규를 준수해야 합니다.\n- **문서 상태**: 손상된 문서나 불법 내용이 포함된 문서는 보관이 불가능할 수 있습니다.\n- **비용 확인**: 신청 시 요구되는 수수료 및 비용을 미리 파악하는 것이 좋습니다.\n\n정확한 절차와 최신 정보는 해당 기관의 공식 웹사이트나 직접 문의하시는 것이 가장 확실합니다. 도움이 필요하시면 언제든지 알려주세요!'
